# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import point
# %matplotlib inline

# %%
states = gpd.read_file(r'F:\zzzzzzzzzzzzzzzzzzzzzzzzzzzzzPYTHON GEOSPATIAL TRY\JUPYTER NOTEBOOK\BANKURA.shp')
states.head()
# Out:
#    id          BLOCK  Population  \
# 0   1        SALTORA       12645
# 1   2         MEJJIA       23546
# 2   3  GANGAJOLGHATI       22551
# 3   4        BORJORA       33857
# 4   5      SONAMUKHI       49562
#
#                                             geometry
# 0  POLYGON ((86.90040 23.64587, 86.91893 23.64111...
# 1  POLYGON ((87.01258 23.62513, 87.01437 23.62526...
# 2  POLYGON ((87.07704 23.48476, 87.07744 23.48516...
# 3  POLYGON ((87.27155 23.49852, 87.27387 23.49732...
# 4  POLYGON ((87.39888 23.42050, 87.40192 23.42011...

# %%
states.plot()
# Out:
# <Axes: >

# %%
states [states.Population > 50000]
# Out:
#     id      BLOCK  Population  \
# 9   10  BISHNUPUR       76521
# 15  16  RANIBANDH      145758
# 16  17     KHATRA       52456
# 19  20  BANKURA 1      789564
#
#                                              geometry
# 9   POLYGON ((87.39683 22.94495, 87.39709 22.94528...
# 15  POLYGON ((86.78065 22.70918, 86.78098 22.70997...
# 16  POLYGON ((86.72277 23.02698, 86.72374 23.02650...
# 19  POLYGON ((86.89369 23.17887, 86.89389 23.17900...

# %%
states [states.Population > 50000].plot()
# Out:
# <Axes: >
